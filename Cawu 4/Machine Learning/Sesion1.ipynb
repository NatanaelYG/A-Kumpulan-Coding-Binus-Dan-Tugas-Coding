# %% [markdown]
# Pandas buat data manipulation -> dataframe
# sklearn -> preprocessing, modeling, evaluasi
# matplotlib -> vidualisasi data
# seaborn -> vidualisasi data
# numpy -> numerical python
# tqdm -> progress bar
#
#
# gradion -> UI Builder
# streamlit -> UI Builder
#
# lambda function
# list/ array slicing
# iterasi -> for, while, foreach
# paradigm sequential
# set dan list

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.iloc[10]
# Out:
# sepal.length       5.4
# sepal.width        3.7
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 10, dtype: object

# %%
df.iloc[5:10]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df["kolom baru"] = 1
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  kolom baru
# 0           5.1          3.5           1.4          0.2  Setosa           1
# 1           4.9          3.0           1.4          0.2  Setosa           1
# 2           4.7          3.2           1.3          0.2  Setosa           1
# 3           4.6          3.1           1.5          0.2  Setosa           1
# 4           5.0          3.6           1.4          0.2  Setosa           1

# %%
df['kolom baru'] = df['sepal.length'] + df['sepal.width']
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  kolom baru
# 0           5.1          3.5           1.4          0.2  Setosa         8.6
# 1           4.9          3.0           1.4          0.2  Setosa         7.9
# 2           4.7          3.2           1.3          0.2  Setosa         7.9
# 3           4.6          3.1           1.5          0.2  Setosa         7.7
# 4           5.0          3.6           1.4          0.2  Setosa         8.6

# %%
df['kategori sepal length'] = df['sepal.length'].apply(lambda x: 'panjang' if x > 5.8 else 'pendek')
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  kolom baru  \
# 0           5.1          3.5           1.4          0.2  Setosa         8.6
# 1           4.9          3.0           1.4          0.2  Setosa         7.9
# 2           4.7          3.2           1.3          0.2  Setosa         7.9
# 3           4.6          3.1           1.5          0.2  Setosa         7.7
# 4           5.0          3.6           1.4          0.2  Setosa         8.6
#
#   kategori sepal length
# 0                pendek
# 1                pendek
# 2                pendek
# 3                pendek
# 4                pendek

# %%
df[df['kategori sepal length']== 'panjang']
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety  \
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   Virginica
# 146           6.3          2.5           5.0          1.9   Virginica
# 147           6.5          3.0           5.2          2.0   Virginica
# 148           6.2          3.4           5.4          2.3   Virginica
# 149           5.9          3.0           5.1          1.8   Virginica
#
#      kolom baru kategori sepal length
# 50         10.2               panjang
# 51          9.6               panjang
# ...

# %%
for row in df.head():
  print(row)
# Out:
# sepal.length
# sepal.width
# petal.length
# petal.width
# variety
# kolom baru
# kategori sepal length

# %%
df[(df['sepal.length'] > 5) & (df['sepal.width'] > 3)]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety  \
# 0             5.1          3.5           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 10            5.4          3.7           1.5          0.2      Setosa
# 14            5.8          4.0           1.2          0.2      Setosa
# 15            5.7          4.4           1.5          0.4      Setosa
# 16            5.4          3.9           1.3          0.4      Setosa
# 17            5.1          3.5           1.4          0.3      Setosa
# 18            5.7          3.8           1.7          0.3      Setosa
# 19            5.1          3.8           1.5          0.3      Setosa
# 20            5.4          3.4           1.7          0.2      Setosa
# 21            5.1          3.7           1.5          0.4      Setosa
# 23            5.1          3.3           1.7          0.5      Setosa
# ...

# %%
df.describe(include='object')
# Out:
#        variety kategori sepal length
# count      150                   150
# unique       3                     2
# top     Setosa                pendek
# freq        50                    80

# %%
df[['sepal.length', 'sepal.width']].plot(kind="scatter", x="sepal.length", y="sepal.width")
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
df[["sepal.length", "sepal.width", "petal.length", "petal.width"]].plot(kind="box")
# Out:
# <Axes: >

# %%
import tqdm

# %%
for i in tqdm.tqdm(range(10000000)):
  pass
# Out:
# 100%|██████████| 10000000/10000000 [00:00<00:00, 10553877.36it/s]

# %%
for i in tqdm.tqdm(df['sepal.length'].apply(lambda x: x**2)):
  pass
# Out:
# 100%|██████████| 150/150 [00:00<?, ?it/s]
